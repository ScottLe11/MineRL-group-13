# %% [markdown]
# # Disclaimer: Our entire project takes a very long time to install and boot up the checkpoint due to minerl being very heavy. Here some videos of our progress.
# ##  Here is a video of the agent performing poorly/starts
# https://drive.google.com/file/d/1cNbzgB6HhRcoP5wkdZf7qnP-FX51pbJ1/view?resourcekey
# ## Here is a video of the agent crafting. How our macros work
# https://drive.google.com/file/d/1OXIOq41TgO14UkO3n3l-BJkmlYlcbJUD/view?resourcekey
# ## Here is a video of our agent performing well
# https://youtu.be/7xZTrC9JOH4

# %% [markdown]
# # If you want to continue here are the directions to set up everything. In terminal because these are not able to run in juypter lab (Make sure to have homebrew and anaconda)

# %% [markdown]
# # Clone from out github so that you can run the checkpoint/model and cd to folder. We do not have dataset

# %%
# !git clone https://github.com/ScottLe11/MineRL-group-13.git
# %cd MineRL-group-13
# Out:
# Cloning into 'MineRL-group-13'...
# remote: Enumerating objects: 883, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (22/22), done.
# Receiving objects: 100% (883/883), 226.38 MiB | 23.07 MiB/s, done.
# remote: Total 883 (delta 11), reused 5 (delta 3), pack-reused 858 (from 3)
# Resolving deltas: 100% (513/513), done.
# Updating files: 100% (78/78), done.
# /Users/brandon/Documents/MineRL-group-13

# %% [markdown]
# # Now follow go into the google doc below and follow to setup the dependencies and setup the biome
# https://docs.google.com/document/d/1JccSKc4-5j6kNcGDYQSs5co9yqHx5lFioGKlbo12PbA/edit?usp=sharing

# %% [markdown]
# # Run the model/checkpoint (This take 2 - 3 mins to show the screen/window)

# %%
# !python -m scripts.train --resume best_model/checkpoint_ppo_ep3000.pt --render
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ...
# MineRL Tree-Chopping RL Training
# ...
# Config: config/config.yaml
# Algorithm: PPO
# Device: mps
# Episodes: 4000
# Episode length: 60s
# Render: True
# Resume: best_model/checkpoint_ppo_ep3000.pt
# ...
# Training on device: mps
# Curriculum config: with_logs=0, with_axe=False, spawn_type=random
# ✓ Created MineRL environment: MineRLcustom_treechop-v0
# Applying environment wrappers...
# Action space: 18 actions (preset: custom)
# ✓ All wrappers applied.
# Environment created: MineRLcustom_treechop-v0
# Action space: Discrete(18)
# Network architecture: medium (3,326,688 params)
# Attention mechanism: cbam
# ...
